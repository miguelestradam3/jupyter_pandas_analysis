# %% [markdown]
# # Welcome To The Practice Notebook
# ---

# %% [markdown]
# Importing the pandas library

# %%
import pandas as pd

# %% [markdown]
# Import the json Imdb Dataset

# %%
# Your code goes here
data = pd.read_json('movies_dataset.json')

# %% [markdown]
# Answer to the following Analytical questions:
#
# Question 1: Use Histograms to compare the disribution of movie `imdb_score` column related to movies produced in `France` and `Canada`.
#
# While creating the histgoram:
# - Set the number of bins to 20
# - Set the xAxis Label
# - Set the yAxis Label
# - Remove the grid lines

# %%
# Create the histogram for Canada here 
dataset = data[data['country'] == 'Canada']
bar = dataset.imdb_score.hist(grid=False, figsize=(10,8), bins=25)
bar.set_title("Movies scores histogram for Canada")
bar.set_xlabel("Scores")
bar.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# Create the histogram for France here 
# Create the histogram for Canada here 
dataset = data[data['country'] == 'France']
bar = dataset.imdb_score.hist(grid=False, figsize=(10,8), bins=25)
bar.set_title("Movies scores histogram for France")
bar.set_xlabel("Scores")
bar.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Question 2: Create a histogram to check the distribution of `imdb_score` spent to produce Black&White movies.
#
# While creating the histgoram:
# - Set the number of bins to 10
# - Set the xAxis Label
# - Set the yAxis Label
# - Remove the grid lines

# %%
#To go back to the tree, click on the Jupyter icon
dataset = data[data['color'] == 'Black and White']
bar = dataset.budget.hist(grid=False, bins=25)
bar.set_title("B&N Movies Budget Histogram")
bar.set_xlabel("Budget")
bar.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')
